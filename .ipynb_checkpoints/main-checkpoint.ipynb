# %%
import facebook_scraper as fs
from facebook_scraper import get_group_info
from facebook_scraper import get_posts
import pandas as pd
import os
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as msno
import openai
from deep_translator import GoogleTranslator

# %%
#read cookies
cookie = 'cookies_data/religious_post.txt'
print(cookie)
# Out:
# cookies_data/religious_post.txt

# %%
#initialize the cookies
get_group_info("368809433220789", cookies= cookie)
# Out:
# /Users/rahadarmannabid/opt/anaconda3/envs/networkx_env/lib/python3.10/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# {'id': '368809433220789',
#  'name': 'বুয়েটে আড়িপেতে শোনা',
#  'type': 'Private group',
#  'members': 22621,
#  'about': 'বুয়েটে আড়িপেতে শোনা বা আড়িপাতা\n\nআড়িপাতা গ্রুপটি শুধু বুয়েটিয়ানদের জন্য এবং জামাত-শিবির মুক্ত। ডাটাবেইজে তথ্য দিয়ে অন্য বুয়েটিয়ানদের যোগ করা যাবে। তথ্য দেয়ার লিঙ্কঃ https://tinyurl.com/SubmitAripataDB\n\nনানা বিষয়ে নির্বাচিত অ্যাডমিন প্যানেলের সিদ্ধান্তই চূড়ান্ত। লেখা/মন্তব্য দেওয়ার জন্য কিছু নিয়মাবলী সংক্ষেপে নিচে দেয়া হলো। পূর্ণ নিয়মাবলীর জন্য আড়িপাতা ৬.০ দ্রষ্টব্য। নীতিমালা গ্রুপের ফাইলে দেয়া আছে।\n১। নিজের লেখা/মন্তব্য চলবে, কিছু শেয়ার করলে সাথে ৫০ শব্দের নিজস্ব ব্যাখ্যা দেওয়া উচিৎ। পোস্ট নিয়ন্ত্রণ ও অতঃপর অনুমোদন নেই, লেখা/মন্তব্যে তাই নিজস্ব বিবেচনা প্রয়োগ করুন।\n২। লেখা/মন্তব্য সম্পর্কে অভিযোগ জানিয়ে প্যানেলের সিদ্ধান্তের অপেক্ষা করুন। সিদ্ধান্ত পছন্দ না হলে যুক্তি দিন, পুনর্বিবেচনার আবেদন করুন।\n৩। আড়িপাতার লেখা/মন্তব্য/স্ক্রিনশট লেখকের/ প্যানেলের অনমুতি ছাড়া বাইরে দেওয়া কাম্য নয়।\n৪। আড়িপাতার ঘটনা নিয়ে আড়িপাতার বাইরে আক্রমণাত্মক লেখা/মন্তব্য/আচরণ কাম্য নয়।\n৫। বুয়েটের ক্লাস /পরীক্ষা/ সেশনাল বর্জন/পিছানোর, PL/ছুটি বাড়ানোর তৎপরতা কাম্য নয়।\n৬। বাংলাদেশের অস্তিত্ববিরোধী কোনো গোষ্ঠীর বিরুদ্ধে নিজের/ বুয়েটিয়ানদের এর ছাড়া অন্য কারো লেখা/মন্তব্য দেয়া উচিত নয়।\n৭। বাংলাদেশের দলীয় রাজনীতি নিয়ে রাজনৈতিক সমর্থকদের মতো করে প্রচারধর্মী লেখা/মন্তব্য দেয়া উচিত নয়। বুয়েট চত্বরের রাজনীতি নিয়ে আলোচনা চলতে পারে। জাতীয় গুরুত্বপূর্ণ বিষয়ে বা রাজনৈতিক/আদর্শ/তাত্ত্
#   {'name': 'Auntara Tithi',
#    'link': '/auntara.madhuri?groupid=368809433220789&eav=AfZ4NAEp4EKKab5nA-2ngZu03WuIAaMKY_v4UTTJXwkcYfgsTnU8L5vys2FOjcxumBo&paipv=0'},
#   {'name': 'Aupurbo Chowdhury',
#    'link': '/aupurbo.chowdhury?groupid=368809433220789&eav=Afa0lG4X22BUhC2o0ttjBh8wj9llXsoIn1A_SnA5EYm8MhuVOwF0UWuhUTukIjZNSis&paipv=0'},
#   {'name': 'Avijit Sazzal',
#    'link': '/avijit.sazzal?groupid=368809433220789&eav=AfZL6AxXrYoHn_Kti8JH6QrZFOrdr4O1-ASOHMR_JCK671WhNNZLf7jW2JYiYNukiIw&paipv=0'},
#   {'name': 'Awsaf Alam',
#    'link': '/awsaf.dev?groupid=368809433220789&eav=AfaL0_rNNFIiNCJ7sKFnB3mp5xKI-ecOyGW1rAKHUM6lkqPFFGt2p_2uCoPhZ8h_VSI&paipv=0'},
#   {'name': 'Awsaf Rahman',
#    'link': '/Awsaf117?groupid=368809433220789&eav=AfaMwv_J3ORmEv4wBotXHQAXyC6zc14T_Z6DnoFQAL2Q63i6BoUE_AUdInBqR2d55mU&paipv=0'}]}

# %%
#getting all the post ids from this group, number of ids depends on the cookies and save it in a csv file
def scrape_facebook_group():
    i = 0
    posts = get_posts(group='368809433220789', cookies= cookie)
    with open('group_post_ids/list.txt', 'w') as f:
        header_title = 'post_id' + ","+ 'post_reactions' + ',' + "num_of_comments" +'\n'
        f.write(header_title)
        for post in posts:
            id_num= post.get('post_id')
            id_reactions = post.get('likes')
            comments_num= post.get("comments")
            entry_csv = str(id_num) + ',' + str(id_reactions) + ',' + str(comments_num)+ '\n'
            f.write(entry_csv)
            i += 1


        

if __name__ == "__main__":
    scrape_facebook_group()
# Out:
# /Users/rahadarmannabid/opt/anaconda3/envs/networkx_env/lib/python3.10/site-packages/dateparser/freshness_date_parser.py:76: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   now = self.get_local_tz().localize(now)

# %%
#convert the text file into csv file
read_file = pd.read_csv (r'group_post_ids/list.txt')
read_file.to_csv (r'group_post_ids/list.csv', index=None)

# %%
group_post_ids = pd.read_csv("group_post_ids/list.csv")
group_post_ids.sort_values(ascending= False, by='num_of_comments',inplace = True)
group_post_ids
# Out:
#               post_id  post_reactions  num_of_comments
# 120  5545405485561132             367              158
# 5     913133025455091             299              134
# 93   5548904708544543             508              109
# 132  5546932162075131              39              104
# 8    5556617347773279             133              101
# ..                ...             ...              ...
# 155  5553368184764862               2                0
# 62   5557976220970725               2                0
# 153  5553616601406687              15                0
# 64   5557884704313210               3                0
# 163  5552780501490297               1                0
#
# [210 rows x 3 columns]

# %%
#save all the comments and replies into a post
def extract_data_from_post(Token_NO):
    POST_ID = "https://www.facebook.com/groups/OverheardAtBUET/posts/"+ Token_NO +"/"
    MAX_COMMENTS = True

    gen = fs.get_posts(
        post_urls=[POST_ID],
        options={"comments": MAX_COMMENTS, "progress": True}
    )

    post = next(gen)
    comments = post['comments_full']

    File_NAME = Token_NO + ".csv"

    i= 0
    temp_data = [[]]

    temp_data[i].append(post['username']) 
    temp_data[i].append(post['post_text']) 

    for comment in comments:
        temp_data.append([])
        i +=1 
        temp_data[i].append(comment.get('commenter_name'))
        temp_data[i].append(comment.get('comment_text'))
        for reply in comment['replies']:
            temp_data[i].append(reply.get('commenter_name')) 
            temp_data[i].append(reply.get('comment_text'))
    File_loaction = 'raw_data_2/' + File_NAME
    temp_data_data_frame = pd.DataFrame(temp_data)
    temp_data_data_frame.to_csv(File_loaction, encoding='utf-8')

# %%
#create csv files of different post with comments
x, y = group_post_ids.shape
for i in range(x):
    extract_data_from_post(str(group_post_ids.iloc[i][0]))
    if i == 10:
        break
# Out:
# /Users/rahadarmannabid/opt/anaconda3/envs/networkx_env/lib/python3.10/site-packages/dateparser/freshness_date_parser.py:76: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   now = self.get_local_tz().localize(now)
#  67%|████████████████████████████▋              | 30/45 [00:01<00:00, 24.66it/s]
#  70%|██████████████████████████████             | 30/43 [00:01<00:00, 28.54it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#  65%|████████████████████████████               | 30/46 [00:01<00:00, 26.00it/s]
#  74%|███████████████████████████████▊           | 60/81 [00:03<00:01, 18.55it/s]
#  75%|████████████████████████████████▎          | 30/40 [00:01<00:00, 27.89it/s]
#  83%|███████████████████████████████████▊       | 30/36 [00:01<00:00, 25.33it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]

# %%
#checking the length of reply of each csv file
def checking_length_of_reply(data):
    #plotting the reply length
    data = data.drop('Unnamed: 0', axis=1)
    not_null_values = data.notnull()
    not_null_values = not_null_values.T
    a, b = not_null_values.shape
    title = [*range(0,b)]
    not_null_values.columns = title
    not_null_values
    list_plot =[]
    for i in range(0, b):
        list_plot.append((not_null_values[i].value_counts()[True])/2)
    comment_number = [*range(0,b)] 
    plt.barh(comment_number,list_plot)
    plt.title('Number of Replies in Each Comment')
    plt.ylabel('Number of Replies in Each Comment')
    plt.xlabel('Comment Number')
    plt.show()

# %%
#read all the file names in the folder
path = "raw_data_2/"
dir_list = os.listdir(path) 
print("Files and directories in '", path, "' :")
print(dir_list, '\n')

#check all the comment reply length
for i in dir_list:
    data = pd.read_csv(path + i)
    checking_length_of_reply(data)
# Out:
# Files and directories in ' raw_data_2/ ' :
# ['5545405485561132.csv', '5548904708544543.csv', '913133025455091.csv', '5554638077971206.csv', '5547247668710247.csv', '5540681289366885.csv', '5554319294669751.csv', '5556901084411572.csv', '5551812894920391.csv', '5546932162075131.csv', '5513840785384269.csv', '5556617347773279.csv', '5548857651882582.csv', '5548099641958383.csv', '5554742511294096.csv']

# %%
def user_database(Token_NO):
    POST_ID = "https://www.facebook.com/groups/OverheardAtBUET/posts/"+ Token_NO +"/"
    MAX_COMMENTS = True
    gen = fs.get_posts(
        post_urls=[POST_ID],
        options={"comments": MAX_COMMENTS, "progress": True}
    )

    post = next(gen)
    comments = post['comments_full']

    user_data = []

    if post['username'] not in user_data:
        user_data.append(post['username'])

    for comment in comments:
        if comment.get('commenter_name') not in user_data:
            user_data.append(comment.get('commenter_name'))
        for reply in comment['replies']:
            if reply.get('commenter_name') not in user_data:
                user_data.append(reply.get('commenter_name'))
    File_NAME = 'user_database/' + Token_NO +'.csv'
    user_data_data_frame = pd.DataFrame(user_data)
    user_data_data_frame.to_csv(File_NAME, encoding='utf-8')
    # user_data_data_frame
    return user_data

# %%
#create user database for each of the post in user_database folder
x, y = group_post_ids.shape
for i in range(x):
    path = "raw_data_2/"
    user_database(str(group_post_ids.iloc[i][0]))
    if i == 10:
        break
# Out:
#  67%|████████████████████████████▋              | 30/45 [00:01<00:00, 22.96it/s]
#  70%|██████████████████████████████             | 30/43 [00:01<00:00, 20.62it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]
#  65%|████████████████████████████               | 30/46 [00:01<00:00, 22.59it/s]
#  74%|███████████████████████████████▊           | 60/81 [00:02<00:01, 20.88it/s]
#  75%|████████████████████████████████▎          | 30/40 [00:01<00:00, 28.71it/s]
#  83%|███████████████████████████████████▊       | 30/36 [00:01<00:00, 25.68it/s]
#   0%|                                          | 0/1000000000.0 [00:00<?, ?it/s]

# %%
def chat_gpt_sentiment(translated_sentence):
    openai.api_key = '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'
    messages = [ {"role": "system", "content": 
                  "You are a intelligent assistant."} ]

    message = "what is the sentiment of this sentence? Answer in one word either positive or negative or neutral?" + translated_sentence
    if message:
        messages.append(
            {"role": "user", "content": message},
        )
        chat = openai.ChatCompletion.create(
            model="gpt-3.5-turbo", messages=messages
        )
    reply = chat.choices[0].message.content
#     print(f"ChatGPT: {reply}")
    messages.append({"role": "assistant", "content": reply})
    if reply.find('positive')!= -1:
        sentiment_value = 100
    elif reply.find('negative')!= -1:
        sentiment_value = -100
    else:
        sentiment_value = 1
    return sentiment_value

# %%
def text_translator(x):
    translated_sentence = GoogleTranslator(source='auto', target='en').translate(x)
    sentiment_value = chat_gpt_sentiment(translated_sentence)
    print(translated_sentence, sentiment_value, '\n')
    return sentiment_value

# %%
def create_adjacency_matrix(TOKEN_ID):
    path_for_user_data ="user_database/" + TOKEN_ID +".csv" 
    path_for_data = "raw_data_2/" + TOKEN_ID + ".csv"
    File_NAME = 'adjacency_matrix_database/'+ TOKEN_ID + ".csv"
    # read the user data
    user_data_raw= pd.read_csv(path_for_user_data )
    #read the post comments and replies
    data_raw = pd.read_csv(path_for_data)
    data = data_raw.drop('Unnamed: 0', axis=1)
    
    #make a list of user data
    user_data = []
    user_data_list = user_data_raw.drop('Unnamed: 0', axis=1)
    p,q = user_data_list.shape
    for i in range(p):
        user_data.append(user_data_list['0'].iloc[i])
        
    embedding_nodes =  translation_chagpt_sentiment(data, user_data)
    embedding_nodes_csv = pd.DataFrame(embedding_nodes)
    embedding_nodes_csv.to_csv(File_NAME, encoding='utf-8')
    
    return embedding_nodes

# %%
def translation_chagpt_sentiment(data, user_data):
    embedding_nodes = np.zeros((len(user_data), len(user_data)))
    a , b = data.shape
    for i in range(0, a):
        for j in range(1, b, 2):
            if len(str(data.iloc[i][j])) > 3:
                s = str(data.iloc[i][j])
                for k in user_data:
                    if s.find(str(k))!= -1:
                        to_whom_replied = user_data.index(str(k))
                        t = str(data.iloc[i][j-1])
                        #print(t,k) #who commented whom
                        for k in user_data:
                            if t.find(str(k))!= -1:
    #                             print(s) #comment text
                                who_replied = user_data.index(str(k))
    #                             print(who_replied, to_whom_replied) #who replierd to whom replied index
                                embedding_nodes[to_whom_replied][who_replied] = embedding_nodes[to_whom_replied][who_replied] + text_translator(s)



    for i in range(0, a):
        t = str(data.iloc[i][0])
        s = str(data.iloc[i][1])
    #     print(t,'\n',s)
        for k in user_data:
            if t.find(str(k))!= -1:
                who_replied = user_data.index(str(k))
                if len(s)>2000:
                    s = s[0:1999]
                print(who_replied)
                print(s)
                try:
                    embedding_nodes[0][who_replied] = embedding_nodes[to_whom_replied][who_replied] + text_translator(str(s))
                except:
                    pass
                
    return embedding_nodes

# %%
x, y = group_post_ids.shape
for i in range(x):
    adj_matrix = create_adjacency_matrix(str(group_post_ids.iloc[i][0]))
    print(i)
    if i == 1:
        break
# Out:
# Zakat cannot be given to Vidyananda because its founder is a Hindu or they are promoters of Hinduism!!
# Our own son Chandra Nath is the founder of Foundation for Humanity, he is also doing a lot of good work. It's up to us to stop him too!!
# Even if we cannot build a good institution in the country of 90% Muslims, it is our religious duty to stop any good institution!! 1
#
# Bipresh Bhushan Talukder, Bro, as far as I know, as per my little knowledge, non-Muslims are prohibited from paying Zakat. But if a non-Muslim has the possibility of becoming a Muslim or if zakat increases his attraction/interest towards Islam, then it can be given.
# I don't know that if there are only non-Muslims in any foundation, zakat cannot be given to them.
# Also, Sadaqah (common charity) can be given to anyone. 1
#
# Abdullah Al Amin Sorry if I'm wrong, reading your comment it seems that one of the many good purposes of Zakat is to convert people with money. 1
#
# Amit Chandra Dey The explanation is quite complicated. Let's say, a Southerner wants to become a Muslim. But doing that will deprive his father of his property. In that case zakat can be given to him, after conversion.
#
# The same was done by the Christian missionaries with the Southals of my village. I personally don't think it's unfair. Because my religion doesn't forbid me to do it either. 1
#
# Abdullah Al Amin means that Zakat can be used to induce conversion! -100
#
# Amit Chandra Dey Quran says that there is no compulsion in religion. Islam can be invited but not forced. That's why if you watch Zakir Naik's video, you will see that before teaching Kalema, he always asks, Are you willing to accept? Is anyone forcing you?
#
# If a person wants to convert to Islam voluntarily but his financial condition is not favorable, then Zakat can be given to that person. It is a sector. And after becoming a Muslim, if you qualify from another sector, you will not get it from this sector. Total eight sectors are mentioned in Quran. 1
#
# Monoj K. Roy tried to answer above. You can take a look if you want. Thanks for asking anyway. 1
#
# Monoj K. Roy Dada, the answer is clear. As missionary Christian Rao Saim takes money from donors and converts poor communities, tribals in different countries by exploiting their scarcity. A relative of my distant relationship was in debt, suddenly one day I heard that he had become a Muslim. After searching, I found that the people of the area had converted to religion by showing greed for money. 1
#
# Monoj K. Roy, Amit Chandra Dey Bhaiya, in such scenario it defeats the purpose of believing in Islam. Maybe, the persons involved in such 'luring to Islam' is at fault. If someone is converting to a religion, it should not be for any worldly reasons except for the sake of the Almighty only.
#
# Regarding Zakat and it being an Islamic rulings, I can present an analogy:
# During the celebration of Eid-ul-Adha (kurbani'r Eid) we slaughter animal as an act of sacrifice. It is our religious custom that 1/3 be distributed to the poor. In Bangladesh's perspective, most of the time it is a cow. Now if I try to distribute beef to people following Hinduism knowingly, that would be a reprehensible act.
# of Hearts) means gifting the people of other faiths.
# 5) Fir-Riqab (those in Bondage)
# 6) Al-Gharimin (Those in Debt)
# 7) Fi-Sabilillah (In the Cause of Allah)
# 8) Ibn-al-Sabil (Travelers unable to return home)
# If you gave other than these categories your zakat will be considered as charity. 1
#
# Al Farabee
# upon your provided Verse and some searching, I found that it is not permissible to give Zakat to non Muslims in the current condition, where Majority of people in here are Muslims. You can give other regular charities to them, no problem, those are even encouraged.
#
# Heres some links -
#
# https://
# islamqa.info/en/
# answers/3854/
# giving-sadaqah-c
# harity-to-non-m
# uslims
# https://
# fb.watch/
# jQHsQvk7Ke/
# ?mibextid=NnVzG8
#
# https://
# youtu.be/
# C7vmWj6Jk38
#
# Hopefully you will find those useful. 1
#
# Imran Emon Vai Did you find anything about giving zakat for study purposes? 1
#
# Al Farabee please talk to someone more eligible regarding this.
#
# I am giving Zakat to an Yateem as cash, how he spends it is his concern as long as he is not doing anything illegal like buying Alcohol with it. 1
#
# Imran Emon Bhai Yatim but there is no provision to give zakat If that orphan is poor then Zakat can be given to him as a poor person. 1
#
# Al Farabee yes, they are poor as well 1
#
# Al Farabee Here is a post in details on our zakat initiative: https://
# www.facebook.com
# /groups/
# OverheardAtBUET/
# posts/
# 5540942632674084
# / 1
#
# Mohammad Abul Hasnat Saikat is basically the group of people who are seen at the root of this catchall, who tag people as Jamaat Shibir when they get a chance, tag them communally, so it is easy to understand which direction their Qibla is! Ignore Them, Let Them Enjoy This World 😴 1
#
# Nishat Sultana - You are absolutely right. 100% agree.
#
# It is surprising to think so much about this zakat in the month of fasting. We should first be good people and then think about how we can please the Creator by practicing our respective religions. 1
#
# Shahnaz Islam Ms. In Islam it is forbidden to exaggerate. To boast that I am more religious, the other is less religious! It is not possible to imagine a person's past prayers, fasting, zakat, hajj, how pure his mind and thoughts are! Only Allah has the power to know the news of the mind. So it is not right for people to exaggerate it! 1
#
# Nishat Sultana - I agree. 1
#
# Chandra Nath if you could disclose in details how this will be spend as per religious rules and how eligible perons are selected, this unwanted debt will be cleared out. 1
#
# SB Mehdi thank you! I have an example in this comment thread. There is a picture as well. Munir Haque and I also posted two posts recently with a bit detailed with examples. Thank you again. 1
#
# SB Mehdi thank you! I have an example in this comment thread. There is a picture as well. Munir Haque and I also posted two posts recently with a bit detailed with examples. Thank you again. 1
#
# SB Mehdi https://
# m.facebook.com/
# groups/
# OverheardAtBUET/
# permalink/
# 5540942632674084
# /
# ?mibextid=Nif5oz 1
#
# Chandra Nath, Thanks. Its in detail. But i could not find that in Biddanondon page. You can put it there again. We always love you and Biddanondon. To make things we will also share this for everyone's clarification. Thanks. We will share the details more for everyone's better understanding. 100
#
# Munir Haque is there any public version post, which i and others can share? 1
#
# Ahsanul Habib Sorov 1
#
# Shahid Al Arif Uzzal is the author 1
#
# Who is Manirul Islam? 1
#
# Sharmin Jahan Sumi They are killing the dough!! -100
#
# It was very sad to see Jahangir Alam promoting some Buetians so badly. 1
#
# Sharmin Jahan Sumi This is our beauty! 1
#
# Sharmin Jahan Sumi Vidyanand does not make someone self-reliant, donors do. And according to Vidyananda's record, the largest donation comes from Muslims. 1
#
# Sharmin Jahan Sumi someone somewhere said Vidyananda bad? Did the words cut through? Bring to admin's attention.
# Vidyananda is an exemplary institution; All agree or will. 1
#
# Shahid Al Arif Uzzal took this https://
# www.facebook.com
# /groups/
# OverheardAtBUET/
# permalink/
# 5544685322299815
# /
# ?mibextid=Nif5oz 1
#
# Shariat Rahman is not in Adipata. 1
#
# Shahid Al Arif Uzzal post sharers and likers are members of Adipata 1
#
# Shariat Rahman, what is the real meaning of the Koran related to Zakat? I want to know that. 1
#
# Bipresh Bhushan Talukder, As far as I know, collection and distribution of Zakat should be Halal if there is a Zakat Board, be it Vidyananda or As Sunnah Foundation.
#
# I know I could be wrong, although I can't find any hard evidence in the last few days, just seeing catchalls.
#
# But the best would be - if you can deliver directly yourself, which is what I always do in my family. 1
#
# Shariat Rahman is the translation of the Koran? 1
#
# Bipresh Bhushan Talukder,
#
# Surely Sadaqah (zakat) is for the poor, the needy, the dependents, those who are impressed, in the way of Allah, and for the wayfarers - this is the decree of Allah. Allah is All-Knowing, All-Wise. (Surah Tawbah 9:60).
#
# It (Zakat) is due to the needy, who cannot walk on the earth for a living because they are engaged in establishing the religion of Allah, and the ignorant (because of self-respect) do not touch anyone, so the ignorant think they are free from need. You will recognize them by their signs (of poverty). They do not beg people. And whatever good you spend, Allah knows best. (Surah Baqarah 2:273)
#
# Here is a detailed description of the 8 sectors https://
# www.hadithbd.com
# /books/link/
# ?id=3333 1
# Bipresh Bhushan Talukder Bhai 8 category people can get Zakat.
# 1. Those who are helpless, poor, beggars.
# 2. Those who are poor, i.e. are in financial trouble but cannot speak openly
# 3. Those who work in Zakat distribution
# 4. In order to attract non-Muslims who are in financial difficulties to Islam. (Udd
# It is important to inform them that in Islam, the rich are obliged to provide financial support to the poor.
#
# 5. If a slave wants to be freed, he
# 6. Indebted person
# 7. A person who devotes himself to the path of God (may say Islamic missionary or responsible type)
# 8. A traveler (Musaf
# R) Whose money is all gone.
#
# Basically, the words of Shariat Bhai's link are simplified except the Arabic sentences and the Islamic background. The details are there. 1
#
# Shariat Rahman targets truth and transparency but sees no problem. Rather, something more can be learned from it. If there is a target to pollute, the self no longer exists. Religion, caste, clan, it's the same everywhere.
#
# Zakat is a sacred initiative, done for the good of society. It is a despicable act to pollute it by 'targeting'! This is where honesty is tested! Questioning its own existence. 1
#
# Chandra Nath, go ahead. We are together inshallah 1
#
# Chandra Nath we all know your good works, keep it up, do not stop please. BTW, Zakat is a religious matter (one of five pillars in Islam). I know you are a good human and a very good organizer - if "Manusher Jonno foundation" accept Zakat (specifically and not talking about regular donation) from muslim donors, please make sure it is being managed by (only) appropriate persons. We thank you very much for your effort towards humanity and wish your good luck. 1
#
# Tipu Islam We have already posted a post answering all these issues: https://
# www.facebook.com
# /groups/
# OverheardAtBUET/
# posts/
# 5540942632674084
# / 1
#
# Ziauddin Alamgir correct. we can do charity, and encourage others to do charity. 1
#
# Chandra Nath Bhai we know that very well, still some people rise up to dispute this institution...
# Prayers and best wishes for... 1
#
#
# Azazul Islam Razon you ask directly in the inbox of their page. They should answer that. If not, you have the right to bash at will. 1
#
# Shariat Rahman Gee bro, a couple of years ago someone uploaded such a youtube video. He contacted two of the board members by phone, who denied being on the board. I am not saying that the video is completely true. But the video that gets such views that people watch and the most important thing is that one has contacted such a direct claim, then Vidyananda should have given some proof to those who are on the board, because at the end of the day they are the ones who want the Zakat money. When you ask for something for a job, it is your responsibility to clear that you have made the appropriate arrangements for that job. If you just write the name, it is not legitimate. But if Vidyananda can't pay it even in three years, then I don't see anything wrong in allowing them to pay Zakat. 1
#
# Azazul Islam Razon That's why I said, inbox them. If they don't give a satisfactory reply, bash them at will. This is justice -100
#
# Abu Bakar Siddique The introduction of Baitul Mal and Zakat to make the world a heaven. During the reign of Caliph Umar (RA), there were no people to receive Zakat. 1
#
# 0
# বিদ্যানন্দ কে যাকাত দেয়া যাবেনা কারন তার প্রতিষ্ঠাতা হিন্দু বা তারা হিন্দুত্ববাদের প্রমোটার!!
# আমাদের নিজেদের ছেলে Chandra Nath কিন্তু মানুষের জন্য ফাউন্ডেশনের প্রতিষ্ঠাতা, সেও অনেক অনেক ভালো কাজ করে চলেছে।তাকেও ঠেকিয়ে দেয়াটা আমাদের আসেই!!
# ৯০% মুসলমানদের দেশে আমরা নিজেরা ভালো প্রতিষ্ঠান দাড় করাতে না পারলেও, যেকোনো ভালো প্রতিষ্ঠান কে রুখে দেয়া আমাদের ঈমানি দায়িত্ব !!
# Zakat cannot be given to Vidyananda because its founder is a Hindu or they are promoters of Hinduism!!
# Our own son Chandra Nath is the founder of Foundation for Humanity, he is also doing a lot of good work. It's up to us to stop him too!!
# Even if we cannot build a good institution in the country of 90% Muslims, it is our religious duty to stop any good institution!! -100
#
# 1
# Bipresh Bhushan Talukder , ভাইয়া আমার অল্প জ্ঞানে আমি যতটুকু জানি সাধারণ নিয়মে অমুসলিমদের যাকাত এর টাকা দিতে নিষেধ করা হয়েছে। কিন্তু অমুসলিম ব্যাক্তির যদি মুসলিম হবার সম্ভাবনা থাকে বা যাকাত দিলে যদি ইসলাম ধর্মের প্রতি আকর্ষন/আগ্রহ বেড়ে যায়, সেক্ষেত্রে দেয়া যায়।
# যে কোন ফাউনন্ডেশনে শুধুমাত্র অমুসলিম কেউ থাকলেই তাদের যাকাত দেয়া যাবেনা, এমনটা আমার জানা নেই।
# এছাড়া, সদাকা (সাধারণ দান) যে কাউকে দেয়া যায়।
# Bipresh Bhushan Talukder, Bro, as far as I know, as per my little knowledge, non-Muslims are prohibited from paying Zakat. But if a non-Muslim has the possibility of becoming a Muslim or if zakat increases his attraction/interest towards Islam, then it can be given.
# I don't know that if there are only non-Muslims in any foundation, zakat cannot be given to them.
# Also, Sadaqah (common charity) can be given to anyone. 1
#
# 9
# Zakaat doesn't depend on people's emotion, it is one of the fundamental pillars of islam. No one forbade anyone to donate money in Bidyanondo. No one is denying their humanitarian projects. But if you guys deny to understand the difference between usual donation and zakaat then I guess you should start reading about your own deen properly.
# Idaning ja dekhtesi bhai re bhai. 5 waqto namaj porena emon manushjon aisha Bidyananda te zakaat dewar jonno haat-paa dhortese (2)
# Zakaat doesn't depend on people's emotion, it is one of the fundamental pillars of islam. No one forbade anyone to donate money in Bidyanondo. No one is denying their humanitarian projects. But if you guys deny to understand the difference between usual donation and zakaat then I guess you should start reading about your own deen properly.
# Idaning ja dekhtesi bhai re bhai. 5 waqto namaj porena emon manushjon aisha Bidyananda te zakaat dewar jonno haat-paa dhortese (2) 1
#
# 10
# আমি কখনও বিদ্যানন্দকে যাকাত দেওয়া প্রমোট করি না বা নিজেও দিবো না! কিন্তু এটা বিদ্যানন্দে দিতে হলে ওদের কিছু গাডলাইন মানতে হবে বা এটা যদি ওরা না মানে এইটা ওদের দেওয়া যাবে না!বিষয়টা তো এতোটুকুই?
#
# কিন্তু এতো রুট ধরে টানাটানি আর হেয় করা,ছোট করা,ট্রল করা নিজের বন্ধুদেরই করতে দেখলাম!এটা কেনো?
# I never promote giving zakat to Vidyananda nor will I give it myself! But to give it to Vidyananda, they have to follow some guidelines or if they don't mean it, it can't be given to them! That's all?
#
# But I saw my friends doing so much pulling and humiliating, belittling, trolling! Why is this? 1
#
# 11
# লোকজন যাকাতের এলিজিবিলিটি নিয়ে গ্রুপে ধোঁয়া উঠায়ে ফেলতেছে। খোঁজ নিলে দেখা যাবে হয়তো এঁদের ৯০% এর নামাজ (৫ ওয়াক্ত), রোযার খবর নাই! আর আসছে ইসলামের ৪ নম্বর টেনেট নিয়ে টানাটানি করতে!
# People are making a fuss about the eligibility of Zakat in the group. If you look, you will see that maybe 90% of them pray (5 times), there is no news of fasting! And coming to pull the number 4 Tenet of Islam! -100
#
# 15
# সমাজের গরীব অসহায় মানুষের জন্য যারা কাজ করেন তাদেরকে আমি খুব খুব শ্রদ্ধা করি। এ ধরনের সংগঠন অনেক দরকার আমাদের দেশে। কেবল হসপিটালে গেলেই দেখা যায় গরীব মানুষ কত অসহায়। তেমনি শিক্ষার জন্য অনেক অনেক সহায়তা দরকার আমাদের মতো গরীব দেশে। যে কোন সাহায্যের সঠিক ব্যবহার অত্যন্ত গুরুত্বপূর্ণ। এইক্ষেত্রে সততা খুব প্রয়োজন।
# I have great respect for those who work for the poor and helpless people of the society. Such organization is much needed in our country. Only by going to the hospital can you see how helpless the poor people are. Similarly, education needs a lot of support in a poor country like ours. Proper use of any aid is very important. Honesty is very important in this case. 1
#
# 5
# অনুদান আর যাকাত এক নয়। বাংলাদেশে বসবাস করে সবাই মুটামুটি এটা জানে, সে যেই ধর্মের লোক হউক না কেন । যাকাত নিয়ে অন্য ধর্মের মানুষজন কথা বলতে আসে ব্যাপারটা কি কোন ভাল ডিসেন্সির মধ্যে পড়ে !! সারা বিশ্বে মুসলিমরা আজ মার খাচ্ছে এটাই হয়ত একটা কারন। কি ইন্ডিয়া, কি কাশ্মীর, কি জেরুজালেম, কি উইঘুর, কি মায়ানমার, সব ধর্মের যেন একটা কমন টার্গেট মুসলিম। কুরআনে যেমন বলা হয়েছিল, ইহুদীরা বলত, ওরা ত মূর্খ, ওদের অর্থসম্পদ নিলে ফেরত দিতে হবে কেন, মূর্খদের প্রতি আমাদের কোন দায়বদ্ধতা নেই। বাইরের এই সমস্যা তার উপর আছে অভ্যন্তরীণ মুনাফিক আর কিউট মুসলিমদের দৌরাত্ম্য। যাকাত বোর্ডের নামে যেই তিনজনের নাম দিয়ে রেখেছে তাদের দুইজনের সাথে যোগাযোগ করে এর সত্যতা পাওয়া যায়নি।
# Donation and Zakat are not the same. Everyone living in Bangladesh knows this, irrespective of their religion. People of other religions come to talk about Zakat, does it fall into any good decency!! This may be one of the reasons why Muslims are being killed all over the world today. What India, what Kashmir, what Jerusalem, what Uighur, what Myanmar, all religions have a common target Muslim. As it was said in the Qur'an, the Jews used to say, they are fools, why should we return their wealth if we take it, we have no responsibility towards fools. On top of this external problem is internal hypocrisy and cute Muslim violence. Contacting two of the three persons named in the name of Zakat Board could not confirm its authenticity. 1
#
# 17
# না জেনে,না বুঝে,শুধু ইমোশন দিয়ে সবকিছু হয়না ভাই। দান করা অবশ্যই যাবে,কিন্তু যাকাতটা ইবাদাতের মধ্যে পড়ে,যেটা স্পেসিফিক রিচুয়াল মানা ছাড়া কবুল হবেনা। এখানে আমার, আপনার মতামতের ৫ পয়সাও দাম নাই। যাকাত ঠিকমত দিলে সমাজের গরিব দু:খীরা,যারা আমার প্রতিবেশি,তারাই
# পাবে প্রত্যক্ষভাবে, এমন না যে এতে কেও বঞ্চিত হবে। আর ইসলামিক ফাউন্ডেশন নাই কে বলছে? আস সুন্নাহ ফাউন্ডেশন আছে,যথেষ্ট ভাল কাজ করে যাচ্ছে।
# Without knowing, without understanding, everything is not done with just emotions, brother. Giving of charity is permissible, but Zakat falls under Ibadah, which is not acceptable unless specific rituals are followed. My opinion here is not worth 5 paise. If you pay Zakat properly, the poor and unfortunate people of the society, those who are my neighbours, are the ones
# will receive directly, so that no one will be deprived of it. Who is saying that there is no Islamic foundation? As Sunnah Foundation is there, working quite well. 1
#
# 18
# জাহাঙ্গীর আলম আমাদের দেশে উচ্চ-মধ্য-নিম্ন
# মধ্যবিত্তের % কত? ৬০%?? অন এভারেজ তাদের যাকাতের পরিমান কত ৬০,০০০-১৫০,০০/
# ফ্যামিলী?? কোন ফ্যামিলির গরীব যাকাত এলিজেবল আত্মীয় স্বজন নাই বা প্রতিবেশী নাই? এই যাকাত এর দ্বায়িত্ব ফুল্ফিল করার জন্য যদি তোমাকে আমাকে বিভিন্ন অর্গানাইজেশনের সাহায্য নেয়া লাগে তাহলে তোমার কথাই রিপিট করা লাগে.. আমরা আমাদের রুট ভুলে গেছি🥲🥲
# Jahangir Alam is high-middle-low in our country
# What is the % of middle class? 60%?? On average their zakat amount is 60,000-150,00/
# Family?? No family poor zakat eligible relatives or neighbors? If you need me to take the help of various organizations to fulfill this duty of Zakat then you need to repeat your words.. We have forgotten our route🥲🥲 1
#
# 19
# Shariat Rahman বিদ্যানন্দে দিলে যে যাকাত আদায় হবে তার পক্ষে হক্কানি আলেমদের রেফারেন্স দেখান।
# বিদ্যানন্দ নিয়ে বিন্দুমাত্র কোন নেগেটিভ কথা কেউ বলছেনা। যা বলছে তা যাকাত কে পাওয়ার যোগ্য এই বিষয় নিয়ে। এটা ইসলামের একটা অংশ। আবেগ এর বিষয় নয়।
# *সাদকা ও যাকাত এক নয়।
# No one is saying anything negative about Vidyananda. What it says is about who is eligible for Zakat. It is a part of Islam. It's not about emotion.
# * Sadaqah and Zakat are not the same. 1
#
# 23
# মারহাবা।
# যার যার পজিশন থেকে নিজের পক্ষে কি সুন্দর করে কনফিডেন্টলি সাফাই গাচ্ছে। কেউ কেউ আবার মডারেট (৫০% হারাম + ৫০% হালাল) মুসলিম প্রমাণের সুযোগ হাতছাড়া করছে না।
# আরো কত কি?
#
# এমন ক্যাচাল না থাকলে এই আড়িপাতাকে স্থবির মনে হয়।
#
# বুয়েটিয়ান স্কলারদের এমনতর ক্যাচাল আমার খুব ভাল্লাগে।
#
# চলুক না এভাবেই।
# Marhaba.
# Everyone sings beautifully and confidently for themselves from their respective positions. Some are not missing the opportunity to prove moderate (50% haram + 50% halal) Muslim.
# How much more?
#
# Without such a catchall, this page feels stagnant.
#
# I love the catchiness of the Buetian scholars.
#
# Let's not go like this. 1
#
# 24
# I'm not really too fussed about the topic, but this is an interesting article on the matter. I'm seeing a lot of "experts" here, and some actual academic research in this area might be interesting to many. https://
# www.google.com/
# url?sa=t&source=
# web&rct=j&url=h
# ttps%3A%2F%2Fsc
# holarworks.iu.e
# du%2Fiupjournal
# s%2Findex.php%2
# Fmuslimphilanth
# ropy%2Farticle%
# 2Fdownload%2F48
# 89%2F345%23%3A%
# 7E%3Atext%3DThe
# %2520Muftis%252
# 0from%2520the%2
# 520Arab%2Ca%252
# 0national%2520p
# oint%2520of%252
# 0view.&ved=2ahU
# KEwiT3Ynj45_-Ah
# WRT8AKHf31CjMQF
# noECA0QBQ&usg=A
# OvVaw3SIUQPXFO0
# 5iM4DOQos8kt
# I'm not really too fussed about the topic, but this is an interesting article on the matter. I'm seeing a lot of "experts" here, and some actual academic research in this area might be interesting to many. https://
# www.google.com/
# url?sa=t&source=
# web&rct=j&url=h
# ttps%3A%2F%2Fsc
# holarworks.iu.e
# du%2Fiupjournal
# s%2Findex.php%2
# Fmuslimphilanth
# ropy%2Farticle%
# 2Fdownload%2F48
# 89%2F345%23%3A%
# 7E%3Atext%3DThe
# %2520Muftis%252
# 0from%2520the%2
# 520Arab%2Ca%252
# 0national%2520p
# oint%2520of%252
# 0view.&ved=2ahU
# KEwiT3Ynj45_-Ah
# WRT8AKHf31CjMQF
# noECA0QBQ&usg=A
# OvVaw3SIUQPXFO0
# 5iM4DOQos8kt 1
#
# 25
# Zakaat is a pillar of Islam. It'd be wise of you all seniors if you don't confuse it with donations. May Allah give you all hidayaah.
# Zakaat is a pillar of Islam. It'd be wise of you all seniors if you don't confuse it with donations. May Allah give you all hidayaah. 1
#
# 26
# একদম ভরে দিছেন। ধন্যবাদ।
# Completely filled. thank you 1
#
# 14
# Without proper knowledge on Islamic regulations, you don't have the right to convert this religious issue into an Emotional Blackmail to the Muslims.
# Zakat is not an emotional thing for anyone to showcase that they are secular and liberal enough to donate to other religions.
# You are free to donate to whoever you want, but not Zakat. It's specific to some categories of people. And there are tons of people that are more suitable for receiving Zakat than a media driven, non-muslim founded organization like Bidyanondo.
#
# The scenario would be whole different if any Muslim would collect the fund for let's say Durga Puja, and say that he would spend it in the proper way by consulting a Brahmin.
#
# Let everyone maintain and perform their Religion as they want.
# Without proper knowledge on Islamic regulations, you don't have the right to convert this religious issue into an Emotional Blackmail to the Muslims.
# Zakat is not an emotional thing for anyone to showcase that they are secular and liberal enough to donate to other religions.
# You are free to donate to whoever you want, but not Zakat. It's specific to some categories of people. And there are tons of people that are more suitable for receiving Zakat than a media driven, non-muslim founded organization like Bidyanondo.
#
# The scenario would be whole different if any Muslim would collect the fund for let's say Durga Puja, and say that he would spend it in the proper way by consulting a Brahmin.
#
# Let everyone maintain and perform their Religion as they want. 1
#
# 27
# Chandra Nath ভাই আপনাদের ফাউন্ডেশন এর কাজ গুলো অত্যন্ত প্রশংসার দাবীদার। যাকাতের সাতটি খাতের মধ্যে একটি গুরুত্বপূর্ণ খাত হচ্ছে ইসলাম প্রচারের নিমিত্তে দরিদ্র অমুসলিমদের সাহায্য করা। আশাকরি ভবিষ্যতে আপনারা দরিদ্র হিন্দু ভাইদের যাকাত এর প্রাপ্য থেকে বঞ্চিত করবেন না। আবার শিক্ষার উদ্দেশ্যে যাকাত এর অর্থ প্রদান এর কোন নিয়ম আছে কি? আমি যতদূর জানি নাই। বাস্তবে টাকার বিনিময়ে হয়ত সার্টিফিকেট পাওয়া যায় কিন্তু শিক্ষার্জন করা যায় না৷ গুরুর প্রতি সম্মান এবং পরিশ্রম এর বিনিময়েই কেবল শিক্ষালাভ হয়৷
# Chandra Nath Bhai, the work of your foundation is highly appreciated. Among the seven sectors of Zakat, one of the most important sectors is helping poor non-Muslims for the sake of spreading Islam. Hopefully in future you will not deprive the poor Hindu brothers of their right to Zakat. Is there any rule for the payment of Zakat for the purpose of education? As far as I don't know. In reality, you can get a certificate in exchange of money but not an education Respect for Guru and hard work is the only way to get education 1
#
# 29
# দান আর যাকাত এটা একজন অমুসলিমের কাছে এক হতে পারে। খুবই স্বাভাবিক। কিন্তু পরিস্কার বিধান থাকার পরও একজন মুসলিমের দান আর যাকাত এর পার্থক্য বুঝতে ব্যাসিক ধারণা থাকলেই হয়, রকেট সায়েন্টিস্ট হওয়া লাগে না। এত এত মেধাবীদের গ্রুপ, এত পড়াশোনা করা মানুষ এরকম একটা ফরয বিধান নিয়ে একটু ব্যাসিক স্টাডি করলে এত সন্দেহ হয় না। কিন্তু আমরা সজ্ঞানে বা অজ্ঞানে এই ইস্যু নিয়ে বেশি জানব না বা জানলেও ইচ্ছে করে মানবো না।
#
# অমুসলিমদের এই রকম একটা ইস্যু নিয়ে তর্ক করলে তাও মানা যায়। মুসলিমদের ফরয একটা বিধান নিয়ে সন্দেহ আর তর্ক থাকার কথা না। ফরয বিধান নিয়ে একজন প্রকৃত মুসলিম কখনো রিস্ক নেওয়ার কথা না। অথচ এটা নিয়ে যে যার মত করে যুক্তি দিয়ে যাচ্ছে। খুব ই দু:খজনক। দিন শেষে এক আল্লাহর কাছে কৃত কর্মের জবাব দিতে হবে। আল্লাহ মাফ করুক। সবাইকে বুঝ দান করুক।
# Abdullah Ibn Mahmud brother! 1
#
# Rakib Hasan brother see it 1
#
# Md. Humayun Kabir is in your list,,,, 1
#
# Marjan Ferdousi Orthy 1
#
# Rafsan Jani Chowdhury, look. 😂😂 1
#
# Rakib Hasan vai 1
#
# My God Rafsan Jani Chowdhury Tere Minde Kaira I sent the photo of quiz chotha to this ID. :v 1
#
# Jasarat Al Atun 1
#
# ^ Arnab Bhattacharjee Bhaiya :D 1
#
# Rakib Hasan tor propic theke chobi niche. Ar tor transcript er chobi.
#
# The fake one is well prepared 1
#
# eitar kothai mone porsu tore boltesilam Rakib Hasan 1
#
# Apu of Kashfia river 1
#
# Kashfia Nehrin apu, Arnab Bhattacharjee bhaia 1
#
# Kashfia Nehrin apu, Arnab Bhattacharjee bhaia 1
#
# Atanu Das brother may be able to tell who he was.
#
# https://
# www.facebook.com
# /bdajk/posts/
# 227203054111683 1
#
# by detective Shaikh Mohammad Alavee 1
#
# Rafsan Jani Chowdhury you should report it as fast as you can! -100
#
# 0
# [সতর্কতামূলক পোস্ট]
#
# ছেলেটার নাম ফায়েদ হাসান। EEE '10 ব্যাচ। বি সেকশনে পড়েন। টিচার হয়ে গেছেন।
#
# এরকম একজন সুযোগ্য ছেলের প্রোপজালে রাজি হয়ে যায় মেডিকালের মেয়েটি। তবে ভাইয়া কোনদিন মেয়েটির সাথে দেখা করতে রাজি হন নি। তিন বছরের লং ডিস্টেন্স রিলেশনশিপে নিজের চেহারাও দেখান নি।
#
# Until, last week. যখন মেয়েটি জানতে পারে যে, ছেলেটি আদৌ বুয়েটের না। তার অন্ধ বিশ্বাস ধ্বংস হয়।
# মেয়েটি বুয়েটের তার ব্যাচের কারো সাথে যোগাযোগ করে জানতে পারে এই নামে কেউই নেই বুয়েটে।
#
# দেখা করার জন্য জোর-জবরদস্তি করে। কিন্তু ছেলেটা দেখা করতে চায় না। বলে যে, রবিবার (কাল) ১১ ব্যাচ EEE এর ক্লাস নিতে হবে সকাল ৮টায়। [আমি ১১ ব্যাচ এবং অবশ্যই তখন কোন ক্লাস নেই]
#
# মেয়েটি ছবি চাইল, ট্রান্সক্রিপ্ট চাইলো। [গত বৃহস্পতিবার] ছেলেটি ১০ ব্যাচের EEE এর জনৈক ভাইয়ার বেশ কিছু ছবি এবং গ্রেডশিটের ছবি দেয়। [সেই ভাইয়ার ট্রান্সক্রিপ্ট ছিনতাই হয়েছিল এবং, তিনি ফেসবুকে পোস্ট দিয়েছিলেন ছবিসহ]
#
# ফায়েদ হাসান এর নাম্বার ট্রুকলার ট্র্যাকিং এ দিয়ে তার আরেকটা Alias পাওয়া গেছে Rafsan.
#
# মেয়েটি কীভাবে তিন বছর না দেখে এরকম কারো সাথে রিলেশন কন্টিনিউ করল, সে বিষয়ে যাব না। তবে, এখন মেয়েটি প্রমাণ চাবার পর নাকি মেয়েটিকে থ্রেট দেয়া শুরু করেছে। ব্ল্যাকমেইল করছে। এমনকি "মেরে ফেলা" এবং "রেইল লাইনে বেধে রাখা"-র হুমকিও দিয়েছে।
#
# এমনিতে, বেশ পরিচিত একজন Fraud এই লোক। বিশেষ করে ১০ ব্যাচের সাথে তার অনেক মিউচুয়াল। এবং, ১০ ব্যাচের সেই ভাইয়ার "ফ্রেন্ডস অনলি" ছবিগুলোও এই ফ্রড পেয়ে যাচ্ছে, যার মানে সে অন্য কোন নামে ১০ ব্যাচের অনেকের সাথেই অ্যাড আছে। ১০ ব্যাচের অনেকের কাহিনীই এই লোক জানে, তবে কারো নাম মেনশন করলাম না।
#
# ১০ ব্যাচের ভাইয়া আপুরাই হয়ত আরো ভাল বলতে পারবেন।
# [warning post]
#
# The boy's name is Fayed Hasan. EEE '10 Batch. Read in B section. Became a teacher.
#
# The medical girl agrees to the proposal of such an eligible boy. But the brother never agreed to meet the girl. He didn't even show himself in a three-year long-distance relationship.
#
# Until, last week. When the girl comes to know that the boy is not from Buet at all. His blind faith is destroyed.
# The girl contacted someone from her batch in BUET and found out that there is no one with this name in BUET.
#
# Forced to meet. But the boy does not want to meet. Says Sunday (tomorrow) 11th batch EEE class to be taken at 8 am. [I am 11th batch and of course no classes then]
#
# The girl asked for photos, transcripts. [Last Thursday] The boy gave several photos and gradesheets of a brother of 10th batch EEE. [That brother's transcript was hacked and he posted it on Facebook with pictures]
#
# Another Alias ​​of Fayed Hasan was found through Truecolor tracking Rafsan.
#
# I won't go into how the girl continued a relationship with someone she hadn't seen for three years. However, now the girl has started threatening the girl after demanding proof. Blackmailing. Even threatened to be "killed" and "tied to railway lines".
#
# In fact, Fraud is a well-known man. Especially its many mutuals with 10 batches. Also, the "friends only" photos of that batch 10 brother are also getting this fraud, which means he has ads with many batch 10 guys under some other name. This guy knows the stories of many of the 10th batch, but I didn't mention anyone's name.
#
# The 10th batch brothers may be able to say it better. -100
#
# 1
# To get effective action one possibility is to let Justice for Women in Bangladesh know the incident with as much as evidences.
# To get effective action one possibility is to let Justice for Women in Bangladesh know the incident with as much as evidences. 1
#
# 2
# Muntasir Shubro dekho er kothai bolsilam. Ekhon naki tomar colleague hoye gese.
# Muntasir Shubro dekho er kothai bolsilam. Ekhon naki tomar colleague hoye gese. 1
#
# 4
# Till now joto fake account dekhlam shobar mutual friend Md. Humayun Kabir! Kemne paro himu?
# Till now joto fake account dekhlam shobar mutual friend Md. Humayun Kabir! Kemne paro himu? 1
#
# 6
# খুব ভাল একটা নাম বেছে নিসে -_-
# Very well chosen name -_- -100
#
# 0
# বাহিরের মানুষ রিলেশন করার জন্য পাগল হয়ে আছে দেখি বুয়েট দেখলেই :/
# Outsiders are crazy about relationships when they see Buet :/ 1
#
# 5
# Tanvir Islam vai, It did not seem to b fake to me while confirming the request. Is Zunayed Shikdar Zenith fake too? If not, he might be asked before just blaming others.
# Tanvir Islam vai, It did not seem to b fake to me while confirming the request. Is Zunayed Shikdar Zenith fake too? If not, he might be asked before just blaming others. -100
#
# 11
# এই পোস্ট পিন করে রাখা উচিত, নাইলে একদিন পরেই এর কথা সবাই ভুলে যাবে, আর এই ব্যাটাও অনেকের ফ্রেন্ডলিস্টে থেকে বুয়েটিয়ান ভাব নিয়ে কুকর্ম চালাইয়া যাবে। :/
# This post should be pinned, otherwise everyone will forget about it after a day, and this guy will be removed from the friend list of many people with a Buetian attitude. :/ 1
#
# 13
# pin dis post plz\\
# pin dis post plz\\ 1
#
# 8
# ভাই পোষ্ট পিন করেন ! আমাদের সবার এই ব্যপারে সচেতন হবার সময় এসেছে :)
# Brother pin the post! Time for us all to be aware of this :) 1
#
# 14
# Report him to the Justice For Women, Bangladesh - JFWBD team. They have handled many such cases.
# Report him to the Justice For Women, Bangladesh - JFWBD team. They have handled many such cases. 1
#
# 15
# Report to the Justice For Women, Bangladesh
# Report to the Justice For Women, Bangladesh 1
#
# 16
# just mutual dekhe add korata stupidity. ami first a accept kri jno profile check korata easy hoy.fake mne hole sathe sathey unfrnd kri
# just mutual dekhe add korata stupidity. ami first a accept kri jno profile check korata easy hoy.fake mne hole sathe sathey unfrnd kri 1
#
# 17
# And then he bologged me :(
# And then he bologged me :( -100
#
# 0
# https://
# m.facebook.com/
# groups/
# 368809433220789?
# view=permalink&
# id=913281012106
# 959
# https://
# m.facebook.com/
# groups/
# 368809433220789?
# view=permalink&
# id=913281012106
# 959 1
#
# 20
# ভাই, আপনার মনে হয় পাবলিকলি দেওয়া উচিত। বুয়েট আর্কির বলে আমার এক পরিচিত আপুর সাথে এমন হইছিল। আমি খবর নিয়ে দেখি এমন কেউ নাই....এগুলা অহরহ হয়। Abdullah Ibn Mahmud; ভাই।
# Brother, you think you should give publicly. According to Buet Arkir, this happened to one of my acquaintances. There's no one I watch on the news....they happen often. Abdullah Ibn Mahmud; brother 1
#
# 18
# ফেইক বুয়েটিয়ান দমন কমিশন গঠন করা দরকার মনে হচ্ছে -_-
# It seems necessary to set up a Fake Buetian Suppression Commission -_- -100
#
# 21
# এই যে আরেকটা,,,বেশ কবার আমাদের '৯৬ ব্যাচের গ্রুপে এড হতে চেয়েছে।ইনবক্সে জানতে চেয়ে কোন রিপ্লাই পাই নাই, এখনো বেশ ক'জন মিউচুয়াল ফ্রেন্ডস আছে।
# Here is another,,,several times have wanted to be added to our '96 batch group. I did not get any reply to the inbox, still there are several mutual friends. 1
#
# 24
# আলাদা একটা পোস্টে এই সবগুলা ID এর link দিয়ে সবাইকে গণহারে রিপোর্ট করতে বলেন, ভাইয়া
# In a separate post, I asked everyone to report all these with the link of the ID, brother 1
#
# 21
# জাহাঙ্গীর আলম
# Jahangir Alam 1
#
# 22
# আব্দুল জব্বার খাঁন ভাই,
#
# সব ফেকু গুলা আপনার ফ্রেন্ড লিস্ট এ। ফ্রেন্ড লিস্ট ফিলটার করতে হবে।
# Brother of Abdul Jabbar Khan,
#
# All feku are in your friend list. Friend list should be filtered. -100
#
# 25
# আমাকে অনেকেই নক দিয়ে এই আইডিটা সম্পর্কে জানতে চাচ্ছেন। একে রিমুভ/রিপোর্ট/
# ডাউন করা দরকার মনে করছি।
#
# https://
# www.facebook.com
# /
# profile.php?id=1
# 00007885757639
# Many people are knocking me and asking to know about this ID. remove it/report/
# I think it needs to be down.
#
# https://
# www.facebook.com
# /
# profile.php?id=1
# 00007885757639 1
#
# 28
# এই একটা https://
# www.facebook.com
# /
# profile.php?id=1
# 00007885757639&
# __mref=message_
# bubble
# This is a https://
# www.facebook.com
# /
# profile.php?id=1
# 00007885757639&
# __mref=message_
# bubble 1
#
# 22
# খাইছে ইনি তোঁ আমার ফ্রেন্ড লিস্ট এ ছিল।
# He was on my friend list. 1
#
# 24
# :(
# 8
# https://
# www.facebook.com
# /
# profile.php?id=1
# 00009503740667&
# fref=ts
# https://
# www.facebook.com
# /
# profile.php?id=1
# 00009503740667&
# fref=ts 1
#
# 32
# আমারা যখন ১ম বর্ষে ,১৯৮৬ইং (১৯৮৪-৮৫ সেশন) ৷ ক্লাশ শুরু হওয়ার প্রায় দূই মাস পর একদিন রাতে তিতুমীর হল(উত্তর) এ চার তলায় হঠাৎ হৈ চৈ শুরু হলো৷ আমাদের সিনিয়ার এক ভাইয়ের রুমে ভূঁয়া বুয়েট ছাত্র ধরা পড়লো৷ তার কাছে ভূঁয়া আইডি কার্ড পাওয়া গেল৷ পরে উত্তম মধ্যম দেওয়ার পর স্বীকার করলো সে ভূয়া এবং ঢাবির এক মেয়ের সাথে প্রেম করার জন্য আর টিউশনির জন্য তার এই প্রতারনা৷
# When we were in 1st year, 1986 (1984-85 session). About two months after the start of the class, one night, there was a sudden uproar on the fourth floor of Titumi's hall (North). A fake BUET student was caught in the room of one of our senior brothers A fake ID card was found with him Later after giving Uttam Madhyam, he admits that he is fake and that he cheated on her for falling in love with a girl from Dubai and for tuition. 1
#
# 33
# In past 2-3 months experienced 3 such incidents. One claimed to be EEE 09. Had a relation with a girl for a long time. Later on, girl had doubts and confirmed that he is fake. Now, the fake id acts weird.
#
# Second claimed to be EEE 10. interestingly he had a propic wearing a tshirt where EEE-10 is written. He also had a long relation with a girl from medical.
#
# third is this Fayed. He for a good period of time was in my list. Later on found out that he is a pure chagu and fake. Somehow he has enormous amount of info regarding our batch. Even he had the pics of our final section photo shoot in buet UG. I was also in one of his cover photo with others -_-
#
# The only remedy is to check id strictly before accepting it. It is better to have less friends than such rats.
# In past 2-3 months experienced 3 such incidents. One claimed to be EEE 09. Had a relation with a girl for a long time. Later on, girl had doubts and confirmed that he is fake. Now, the fake id acts weird.
#
# Second claimed to be EEE 10. interestingly he had a propic wearing a tshirt where EEE-10 is written. He also had a long relation with a girl from medical.
#
# third is this Fayed. He for a good period of time was in my list. Later on found out that he is a pure chagu and fake. Somehow he has enormous amount of info regarding our batch. Even he had the pics of our final section photo shoot in buet UG. I was also in one of his cover photo with others -_-
#
# The only remedy is to check id strictly before accepting it. It is better to have less friends than such rats. 1
#
# 35
# আমার রোলের এক ভুয়া স্টুডেন্ট আইডির সন্ধান পাওয়া গেছে।আইডির সবই ঠিকাছে কিন্তু ছবি আর নামটা ভিন্ন।সে কে,কোথাকার সেটা খুজে পাওয়াটাও দুষ্কর :3
# I found a fake student ID in my roll. Everything about the ID is correct but the picture and name are different. It is difficult to find out who he is and where he is from :3 1
#
# 36
# এ কেমন আয়নাবাজি!
# What kind of mirroring! 1
#
# 37
# I was thinking after reading first few lines-who was this Fayed Hasan, pass kore fellam r nam e janina eki section e theke!🙄
# I was thinking after reading first few lines-who was this Fayed Hasan, pass kore fellam r nam e janina eki section e theke!🙄 -100
#
# 0
# বর্তমান ফেইক আইডি:
#
# https://
# www.facebook.com
# /
# profile.php?id=1
# 00013158963518&
# fref=ts
# Current Fake ID:
#
# https://
# www.facebook.com
# /
# profile.php?id=1
# 00013158963518&
# fref=ts 1
#
# 40
# 3 boshor na dekhe kmne possible !! eita amr mathay dhuktese na !
# 3 boshor na dekhe kmne possible !! eita amr mathay dhuktese na ! -100
#
# 0
# লিখা মেকানিকাল, ছবি ইলেক্ট্রিকাল। অদ্ভুত ব্যাপার, আইডিটা একদা রিয়াল ছিল মনে হচ্ছে।
#
# https://
# www.facebook.com
# /bdajk?fref=ts
# Written Mechanical, Picture Electrical. Oddly enough, the ID seems to have been real once.
#
# https://
# www.facebook.com
# /bdajk?fref=ts 1
#
# 0
# another.
#
# studies phx at BUET
#
#
# https://
# www.facebook.com
# /
# rafsanjanichowdh
# ury01
# another.
#
# studies phx at BUET
#
#
# https://
# www.facebook.com
# /
# rafsanjanichowdh
# ury01 1
#
# 51
# সে বুয়েটের ফুটবলের গ্রুপগুলোতেও একটিভ। বেশ কিছুদিন আগে আমি, লাজ আর কাশফিয়া একে ডিটেক্ট করি। এরপর সে আমাদের ব্লক দিয়ে দেয়। ফেসবুকে দারুণ এক্টিভ এবং বুয়েটের নাম ভাঙ্গায় সবখানে।
# He is also active in BUET's football groups. A few days ago I, Laz and Kashfia detected it. Then he gave us the block. Very active on Facebook and Buet's name is broken everywhere. 1
#
# 52
# পুরনো কাহিনী মনে করায় দিলে
# Reminds me of an old story 1
#
# 2
# Oh my God ! Toke knock diye ei ***** er kothai bolsilam mone ase ?
# He knows every single thing about our batch. He had mutual frnd with every single other girls in my batch. Suddenly he knocked me and to gain my faith he started telling me about the senior apus of 09, 08 batch and then he mentioned 3-4 girls of my batch saying that those girls are his best frnds. I was surprised as I didn't ask anything. Then he said many gossips about buetian couples to prove his credibility as a buetian. When I started to doubt him tokhon ekbar bolse she EEE A section arekbarbolse B section, pore oikhaner frnd der shathe kotha bole ami sure ei hoisi j ei abal jiboneo eshob class er na. R jei meyeder nam bolse amader batch er oder koyekjoner shatheo kotha bolsi, ora toh hotobak as he successfully made them believe j she kon hall er kon room e thake, kon section e pore.
# Pore caught korar aagei deactivate kore dise.
# Tar profile ghete dekhsilam she deactivate korar aagei. She ekjon CHHAGU , amar ekhon post ta pore khub e bhoy lagtese.
# Oh my God! Toke knock diye ei ***** er kothai bolsilam mone ase ?
# He knows every single thing about our batch. He had mutual frnd with every single other girls in my batch. Suddenly he knocked me and to gain my faith he started telling me about the senior apus of 09, 08 batch and then he mentioned 3-4 girls of my batch saying that those girls are his best friends. I was surprised as I didn't ask anything. Then he said many gossips about Buetian couples to prove his credibility as a Buetian. When I started to doubt him tokhon ekbar bolse she EEE A section arekbarbolse B section, pore oikhaner frnd der shathe kotha bole ami sure ei hoisi j ei abal jiboneo eshob class er na. R jei meyeder nam bolse amader batch er oder koyekjoner shatheo kotha bolsi, ora toh hotobak as he successfully made them believe j she kon hall er kon room e thake, kon section e pore.
# Pore ​​caught korar aagei deactivate kore dise.
# Tar profile ghete dekhsilam she deactivate korar aagei. She ekjon CHHAGU , amar ekhon post ta pore khub e bhoy lagtese. 1
#
# 12
# সব প্রোফাইল ফেইক হিসাবে রিপোর্ট কর। ফেসবুক আজকাল বেশ কড়া, একাউন্ট বন্ধ হবে আশা করি।
# Report all profiles as fake. Facebook is quite strict these days, I hope the account will be closed. 1
#
# 0
# https://
# www.facebook.com
# /bdajk/posts/
# 319082324923755
# https://
# www.facebook.com
# /bdajk/posts/
# 319082324923755 1
#
# 0
# Atanu Das ভাইয়া হয়ত বলতে পারবেন ইনি কে ছিলেন।
#
# https://
# www.facebook.com
# /bdajk/posts/
# 227203054111683
# Atanu Das brother may be able to tell who he was.
#
# https://
# www.facebook.com
# /bdajk/posts/
# 227203054111683 1
#
# 0
# https://
# www.facebook.com
# /notes/
# rafsan-jani/
# আমার-ফেসবুক-বিড়ম
# ্বনা/
# 227540247411297
#
#
# 1. 08 e buet e dhukse
# https://
# www.facebook.com
# /notes/
# rafsan-jani/
# my-facebook-weird
# tone/
# 227540247411297
#
#
# 1. 08 e buet e dhukse 1
#
# 1

# %%
# create_adjacency_matrix('913133025455091')

# %%
# Create a directed weighted multigraph from the adjacency matrix
G = nx.MultiDiGraph()

# Add edges with weights as edge attributes
for i in range(adj_matrix.shape[0]):
    for j in range(adj_matrix.shape[1]):
        weight = adj_matrix[i, j]
        if weight != 0 or i == j:  # Include self-loops
            G.add_edge(i, j, weight=weight)

# Draw the graph
pos = nx.spring_layout(G, k=1)  # Choose a layout for the graph with increased repulsion between nodes

# Draw edges with different colors based on their weights
edge_colors = [d['weight'] for u, v, d in G.edges(data=True)]
edge_labels = {(u, v): d['weight'] for u, v, d in G.edges(data=True)}  # Create a dictionary of edge labels

node_labels = {i: i for i in G.nodes()}  # Create a dictionary of node labels
node_sizes = [300 * len(G.out_edges(n)) for n in G.nodes()]  # Set node sizes based on out-degree

nx.draw_networkx_nodes(G, pos, node_color='lightblue', node_size=node_sizes, alpha=0.8)
nx.draw_networkx_edges(G, pos, edge_color=edge_colors, edge_cmap=plt.cm.Blues, edge_vmin=min(edge_colors),
                       edge_vmax=max(edge_colors), arrowsize=20, connectionstyle='arc3, rad = 0.3')
nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=12, font_color='black')
# nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=10)

# Show the graph
ax = plt.gca()
ax.margins(0)
plt.title('Directed Weighted Multigraph (with Self-Loops) from Adjacency Matrix')
plt.colorbar(plt.cm.ScalarMappable(cmap=plt.cm.Blues), label='Weight')
plt.axis('off')
plt.tight_layout()
plt.figure(figsize=(200,100))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[258], line 5
#       2 G = nx.MultiDiGraph()
#       4 # Add edges with weights as edge attributes
# ----> 5 for i in range(adj_matrix.shape[0]):
#       6     for j in range(adj_matrix.shape[1]):
#       7         weight = adj_matrix[i, j]
#
# NameError: name 'adj_matrix' is not defined
